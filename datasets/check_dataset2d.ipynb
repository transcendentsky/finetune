# %%
import numpy as np
from tutils.mn.data import itk_to_np, np_to_itk, read, write

path = "/home1/quanquan/datasets/KiTS/imagesTr/KiTS_case_00000_1000.nii.gz"
data = itk_to_np(read(path))
data.shape
# Out:
# (512, 512, 611)

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import os
os.chdir("/home1/quanquan/code/projects/medical-guangdong/")

data = "cache/data2d/0008_s0000_img.npy"

data = np.load(data)
data = np.clip(data, -100,200)
plt.imshow(data)
